# %% [markdown]
# ## Import Library

# %%
# file: xgboost_pt.ipynb
# # %pip install mlflow
# %pip install xgboost

# %% [markdown]
# ## Import Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.metrics import mean_squared_error, mean_absolute_error
from xgboost import XGBRegressor

# %%
def prepare_weekly_city(df_raw, city_name):
    df_city = df_raw[df_raw["City"] == city_name].copy()
    df_city["Date"] = pd.to_datetime(df_city["Date"])
    df_city = df_city.set_index("Date").sort_index()

    agg_dict = {
        "Cases": "sum",
        "Precip": "sum",
        "Pressure": "mean",
        "Tmean": "mean",
        "Tmin": "mean",
        "Tmax": "mean",
        "Humidity": "mean",
        "Windspeed": "mean",
        "BI": "mean",
        "HI": "mean",
        "CI": "mean",
        "PopDensity_km2": "mean",
    }

    # 1) Weekly aggregation with regular weekly index
    df_weekly = df_city.resample("W").agg(agg_dict).asfreq("W")

    # 2) Handle cases (if any NaN after resample, treat as 0)
    df_weekly["Cases"] = df_weekly["Cases"].fillna(0)

    # 3) Weather interpolation
    weather_cols = ["Precip", "Pressure", "Tmean", "Tmin", "Tmax",
                    "Humidity", "Windspeed"]
    df_weekly[weather_cols] = (
        df_weekly[weather_cols]
        .interpolate(method="time")
        .ffill()
        .bfill()
    )

    # 4) Mosquito indices: carry-forward then backward
    index_cols = ["BI", "HI", "CI"]
    df_weekly[index_cols] = df_weekly[index_cols].ffill().bfill()

    return df_weekly

# %% [markdown]
# ## Load daily data & filter Pingtung

# %%
# Load merged daily dataset
df_raw = pd.read_csv("../data/3_df_merged_cleaned.csv")


df_ks = prepare_weekly_city(df_raw, "Pingtung County")

# %% [markdown]
# ## Aggregate to weekly data

# %%
agg_dict = {
    "Cases": "sum",        # weekly total cases
    "Precip": "sum",       # weekly total rain

    "Pressure": "mean",
    "Tmean": "mean",
    "Tmin": "mean",
    "Tmax": "mean",
    "Humidity": "mean",
    "Windspeed": "mean",

    "BI": "mean",
    "HI": "mean",
    "CI": "mean",

    "PopDensity_km2": "mean"  # constant, but mean is fine
}

df_ks_weekly = df_ks.resample("W").agg(agg_dict)

df_ks_weekly.info()
df_ks_weekly.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 784 entries, 2010-01-03 to 2025-01-05
# Freq: W-SUN
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Cases           784 non-null    float64
#  1   Precip          784 non-null    float64
#  2   Pressure        784 non-null    float64
#  3   Tmean           784 non-null    float64
#  4   Tmin            784 non-null    float64
#  5   Tmax            784 non-null    float64
#  6   Humidity        784 non-null    float64
#  7   Windspeed       784 non-null    float64
#  8   BI              784 non-null    float64
#  9   HI              784 non-null    float64
#  10  CI              784 non-null    float64
#  11  PopDensity_km2  784 non-null    float64
# dtypes: float64(12)
# memory usage: 79.6 KB
#             Cases  Precip     Pressure      Tmean       Tmin       Tmax  \
# Date
# 2010-01-03    0.0    0.16  1012.746667  21.273333  18.933333  23.966667
# 2010-01-10    0.0    0.06  1013.628571  21.115714  18.642857  24.071429
# 2010-01-17    0.0    0.07  1019.192857  19.285714  17.257143  21.885714
# 2010-01-24    0.0    0.09  1017.522857  22.442857  20.485714  25.142857
# 2010-01-31    0.0    0.43  1015.321429  22.762857  20.385714  25.842857
#
#              Humidity  Windspeed        BI        HI        CI  PopDensity_km2
# Date
# 2010-01-03  73.770000   2.916667  4.226100  3.935400  5.861800      290.437626
# 2010-01-10  66.098571   3.761429  4.226100  3.935400  5.861800      290.437626
# 2010-01-17  59.665714   4.881429  4.159714  2.505071  6.699714      290.437626
# 2010-01-24  68.300000   4.958571  0.981214  0.981214  1.543586      290.437626
# 2010-01-31  74.665714   3.664286  1.904936  1.639257  4.319379      290.437626

# %% [markdown]
# ## Add lag features

# %%
lags = [1, 2, 4, 8, 10, 11, 12, 15]

# %%
def add_lag_features(df, lag_cols, lags):
    """
    df: DataFrame with Date index (weekly)
    lag_cols: list of column names to lag
    lags: list of integers, lag in weeks
    
    Returns: new DataFrame with added lag columns
    """
    df = df.copy()
    for col in lag_cols:
        for lag in lags:
            df[f"{col}_lag{lag}"] = df[col].shift(lag)
    return df

# %%
lag_cols = ["Cases", "Tmean", "Tmin", "Tmax",
            "BI", "HI", "CI",
            "Precip", "Humidity"]

lags = [1, 2, 4, 8, 10, 11, 12, 15]

df_lagged = add_lag_features(df_ks_weekly, lag_cols, lags)

# Drop initial rows where lagged values are NaN
df_lagged = df_lagged.dropna().copy()

df_lagged.head()
#
# Out:
#             Cases  Precip     Pressure      Tmean       Tmin       Tmax  \
# Date
# 2010-04-18    0.0    0.16  1012.568571  24.894286  22.042857  28.614286
# 2010-04-25    0.0    0.72  1010.641429  26.024286  23.257143  29.371429
# 2010-05-02    0.0    1.08  1011.704286  24.602857  22.328571  27.157143
# 2010-05-09    0.0    0.16  1006.005714  27.188571  24.642857  30.242857
# 2010-05-16    0.0    0.14  1007.122857  27.382857  24.657143  30.714286
#
#              Humidity  Windspeed        BI        HI  ...  Precip_lag12  \
# Date                                                  ...
# 2010-04-18  71.171429   4.375714  1.901955  1.728608  ...          0.09
# 2010-04-25  70.624286   3.425714  2.585933  2.062211  ...          0.43
# 2010-05-02  67.135714   3.420000  2.828756  1.997081  ...          0.00
# 2010-05-09  71.925714   2.392857  2.584999  2.003567  ...          0.06
# 2010-05-16  71.375714   2.337143  1.856738  1.516665  ...          0.56
#
#             Precip_lag15  Humidity_lag1  Humidity_lag2  Humidity_lag4  \
# Date
# 2010-04-18          0.16      71.931429      66.398571      75.045714
# 2010-04-25          0.06      71.171429      71.931429      69.391429
# 2010-05-02          0.07      70.624286      71.171429      66.398571
# 2010-05-09          0.09      67.135714      70.624286      71.931429
# 2010-05-16          0.43      71.925714      67.135714      71.171429
#
#             Humidity_lag8  Humidity_lag10  Humidity_lag11  Humidity_lag12  \
# Date
# 2010-04-18      70.364286       78.521429       74.665714       68.300000
# 2010-04-25      76.614286       76.857143       78.521429       74.665714
# 2010-05-02      77.894286       70.364286       76.857143       78.521429
# 2010-05-09      71.105714       76.614286       70.364286       76.857143
# 2010-05-16      75.045714       77.894286       76.614286       70.364286
#
#             Humidity_lag15
# Date
# 2010-04-18       73.770000
# 2010-04-25       66.098571
# 2010-05-02       59.665714
# 2010-05-09       68.300000
# 2010-05-16       74.665714
#
# [5 rows x 84 columns]

# %%
df_lagged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 769 entries, 2010-04-18 to 2025-01-05
# Freq: W-SUN
# Data columns (total 84 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Cases           769 non-null    float64
#  1   Precip          769 non-null    float64
#  2   Pressure        769 non-null    float64
#  3   Tmean           769 non-null    float64
#  4   Tmin            769 non-null    float64
#  5   Tmax            769 non-null    float64
#  6   Humidity        769 non-null    float64
#  7   Windspeed       769 non-null    float64
#  8   BI              769 non-null    float64
#  9   HI              769 non-null    float64
#  10  CI              769 non-null    float64
#  11  PopDensity_km2  769 non-null    float64
#  12  Cases_lag1      769 non-null    float64
#  13  Cases_lag2      769 non-null    float64
#  14  Cases_lag4      769 non-null    float64
#  15  Cases_lag8      769 non-null    float64
#  16  Cases_lag10     769 non-null    float64
#  17  Cases_lag11     769 non-null    float64
#  18  Cases_lag12     769 non-null    float64
#  19  Cases_lag15     769 non-null    float64
#  20  Tmean_lag1      769 non-null    float64
#  21  Tmean_lag2      769 non-null    float64
#  22  Tmean_lag4      769 non-null    float64
#  23  Tmean_lag8      769 non-null    float64
#  24  Tmean_lag10     769 non-null    float64
#  25  Tmean_lag11     769 non-null    float64
#  26  Tmean_lag12     769 non-null    float64
#  27  Tmean_lag15     769 non-null    float64
#  28  Tmin_lag1       769 non-null    float64
#  29  Tmin_lag2       769 non-null    float64
#  30  Tmin_lag4       769 non-null    float64
#  31  Tmin_lag8       769 non-null    float64
#  32  Tmin_lag10      769 non-null    float64
#  33  Tmin_lag11      769 non-null    float64
#  34  Tmin_lag12      769 non-null    float64
#  35  Tmin_lag15      769 non-null    float64
#  36  Tmax_lag1       769 non-null    float64
#  37  Tmax_lag2       769 non-null    float64
#  38  Tmax_lag4       769 non-null    float64
#  39  Tmax_lag8       769 non-null    float64
#  40  Tmax_lag10      769 non-null    float64
#  41  Tmax_lag11      769 non-null    float64
#  42  Tmax_lag12      769 non-null    float64
#  43  Tmax_lag15      769 non-null    float64
#  44  BI_lag1         769 non-null    float64
#  45  BI_lag2         769 non-null    float64
#  46  BI_lag4         769 non-null    float64
#  47  BI_lag8         769 non-null    float64
#  48  BI_lag10        769 non-null    float64
#  49  BI_lag11        769 non-null    float64
#  50  BI_lag12        769 non-null    float64
#  51  BI_lag15        769 non-null    float64
#  52  HI_lag1         769 non-null    float64
#  53  HI_lag2         769 non-null    float64
#  54  HI_lag4         769 non-null    float64
#  55  HI_lag8         769 non-null    float64
#  56  HI_lag10        769 non-null    float64
#  57  HI_lag11        769 non-null    float64
#  58  HI_lag12        769 non-null    float64
#  59  HI_lag15        769 non-null    float64
#  60  CI_lag1         769 non-null    float64
#  61  CI_lag2         769 non-null    float64
#  62  CI_lag4         769 non-null    float64
#  63  CI_lag8         769 non-null    float64
#  64  CI_lag10        769 non-null    float64
#  65  CI_lag11        769 non-null    float64
#  66  CI_lag12        769 non-null    float64
#  67  CI_lag15        769 non-null    float64
#  68  Precip_lag1     769 non-null    float64
#  69  Precip_lag2     769 non-null    float64
#  70  Precip_lag4     769 non-null    float64
#  71  Precip_lag8     769 non-null    float64
#  72  Precip_lag10    769 non-null    float64
#  73  Precip_lag11    769 non-null    float64
#  74  Precip_lag12    769 non-null    float64
#  75  Precip_lag15    769 non-null    float64
#  76  Humidity_lag1   769 non-null    float64
#  77  Humidity_lag2   769 non-null    float64
#  78  Humidity_lag4   769 non-null    float64
#  79  Humidity_lag8   769 non-null    float64
#  80  Humidity_lag10  769 non-null    float64
#  81  Humidity_lag11  769 non-null    float64
#  82  Humidity_lag12  769 non-null    float64
#  83  Humidity_lag15  769 non-null    float64
# dtypes: float64(84)
# memory usage: 510.7 KB

# %% [markdown]
# ## Train/Test split by time

# %%
train = df_lagged.loc[df_lagged.index < "2022-01-01"].copy()
test  = df_lagged.loc[df_lagged.index >= "2022-01-01"].copy()

print(train.shape, test.shape)
# Out:
# (611, 84) (158, 84)

# %% [markdown]
# ## Define Features and target

# %%
# Target (weekly cases)
y_train = train["Cases"].values
y_test  = test["Cases"].values

# Features: all columns except Cases
feature_cols = [c for c in df_lagged.columns if c != "Cases"]

X_train = train[feature_cols].values
X_test  = test[feature_cols].values

len(feature_cols), feature_cols[:10]
# Out:
# (83,
#  ['Precip',
#   'Pressure',
#   'Tmean',
#   'Tmin',
#   'Tmax',
#   'Humidity',
#   'Windspeed',
#   'BI',
#   'HI',
#   'CI'])

# %% [markdown]
# ## Fit XGBoost Model

# %%
from xgboost import XGBRegressor

xgb_model = XGBRegressor(
    objective="reg:squarederror",
    n_estimators=500,
    max_depth=3,
    learning_rate=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42
)

xgb_model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=3,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=500,
#              n_jobs=None, num_parallel_tree=None, ...)

# %% [markdown]
# ## Evaluate on test set

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np

# Predictions
y_pred = xgb_model.predict(X_test)

# Metrics
mse  = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae  = mean_absolute_error(y_test, y_pred)
r2   = r2_score(y_test, y_pred)

# Print neatly
print(f"MSE  : {mse:.4f}")
print(f"RMSE : {rmse:.4f}")
print(f"MAE  : {mae:.4f}")
print(f"R²   : {r2:.4f}")
# Out:
# MSE  : 9.4341
# RMSE : 3.0715
# MAE  : 1.3107
# R²   : 0.8433

# %% [markdown]
# ## Plot actual vs predicted over time

# %%
plt.figure(figsize=(12,6))
plt.plot(test.index, y_test, label="Actual Cases", color="black")
plt.plot(test.index, y_pred, label="Predicted Cases", color="red")
plt.title("XGBoost – Weekly Dengue Cases (Pingtun) – Test Set")
plt.xlabel("Date")
plt.ylabel("Weekly Cases")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Feature IMportance

# %%
importances = xgb_model.feature_importances_
fi = pd.Series(importances, index=feature_cols).sort_values(ascending=False)

plt.figure(figsize=(8,10))
fi.head(20).plot(kind="barh")
plt.gca().invert_yaxis()
plt.title("Top 20 Feature Importances (XGBoost)")
plt.xlabel("Importance")
plt.show()

# %% [markdown]
# ## Hyperparameter tuning

# %%
train = df_lagged.loc[df_lagged.index < "2022-01-01"].copy()
test  = df_lagged.loc[df_lagged.index >= "2022-01-01"].copy()

# %%
# Train/test split (you already have this)
train = df_lagged.loc[df_lagged.index < "2022-01-01"].copy()
test  = df_lagged.loc[df_lagged.index >= "2022-01-01"].copy()

# Further split train into train_inner and val by date
val_start = "2018-01-01"   # you can adjust this
train_inner = train.loc[train.index < val_start].copy()
val_df      = train.loc[train.index >= val_start].copy()

print("Train inner:", train_inner.shape)
print("Validation :", val_df.shape)
print("Test       :", test.shape)
# Out:
# Train inner: (403, 84)
# Validation : (208, 84)
# Test       : (158, 84)

# %%
# Target
y_train_inner = train_inner["Cases"].values
y_val         = val_df["Cases"].values
y_test        = test["Cases"].values

# Features
feature_cols = [c for c in df_lagged.columns if c != "Cases"]

X_train_inner = train_inner[feature_cols].values
X_val         = val_df[feature_cols].values
X_test        = test[feature_cols].values

# %%
param_grid = {
    "max_depth":        [2, 3, 4, 8],
    "learning_rate":    [0.01, 0.05, 0.07],
    "n_estimators":     [500, 600, 800],
    "subsample":        [0.8, 1.0],
    "colsample_bytree": [0.8, 1.0],  # (recommended to include)
    "random_state":     [42]              # fixed parameter must still be a list
}

# %%
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error
import numpy as np
import pandas as pd
from itertools import product

results = []

for max_depth, learning_rate, n_estimators, subsample, colsample_bytree in product(
    param_grid['max_depth'],
    param_grid['learning_rate'],
    param_grid['n_estimators'],
    param_grid['subsample'],
    param_grid['colsample_bytree'],
):
    print(f"\nTrying: max_depth={max_depth}, lr={learning_rate}, "
          f"n_estimators={n_estimators}, subsample={subsample}, "
          f"colsample_bytree={colsample_bytree}")

    model = XGBRegressor(
        objective="reg:squarederror",
        max_depth=max_depth,
        learning_rate=learning_rate,
        n_estimators=n_estimators,
        subsample=subsample,
        colsample_bytree=colsample_bytree,
        random_state=42
    )

    # 👇 no eval_metric, no verbose
    model.fit(X_train_inner, y_train_inner)

    # Predict on validation set
    y_val_pred = model.predict(X_val)
    rmse_val = np.sqrt(mean_squared_error(y_val, y_val_pred))
    print(f"  -> val RMSE: {rmse_val:.4f}")

    results.append({
        "max_depth": max_depth,
        "learning_rate": learning_rate,
        "n_estimators": n_estimators,
        "subsample": subsample,
        "colsample_bytree": colsample_bytree,
        "val_rmse": rmse_val
    })

results_df = pd.DataFrame(results).sort_values("val_rmse")
results_df.head()
# Out:
# Trying: max_depth=2, lr=0.01, n_estimators=500, subsample=0.8, colsample_bytree=0.8
#   -> val RMSE: 0.7029
#
# Trying: max_depth=2, lr=0.01, n_estimators=500, subsample=0.8, colsample_bytree=1.0
#   -> val RMSE: 0.6563
#
# Trying: max_depth=2, lr=0.01, n_estimators=500, subsample=1.0, colsample_bytree=0.8
#   -> val RMSE: 0.6480
#
# Trying: max_depth=2, lr=0.01, n_estimators=500, subsample=1.0, colsample_bytree=1.0
#   -> val RMSE: 0.6127
#
# Trying: max_depth=2, lr=0.01, n_estimators=600, subsample=0.8, colsample_bytree=0.8
#   -> val RMSE: 0.7030
#
# Trying: max_depth=2, lr=0.01, n_estimators=600, subsample=0.8, colsample_bytree=1.0
#   -> val RMSE: 0.6631
#
# Trying: max_depth=2, lr=0.01, n_estimators=600, subsample=1.0, colsample_bytree=0.8
#   -> val RMSE: 0.6790
#
# Trying: max_depth=2, lr=0.01, n_estimators=600, subsample=1.0, colsample_bytree=1.0
#   -> val RMSE: 0.6445
#
# Trying: max_depth=2, lr=0.01, n_estimators=800, subsample=0.8, colsample_bytree=0.8
#   -> val RMSE: 0.7353
#
# Trying: max_depth=2, lr=0.01, n_estimators=800, subsample=0.8, colsample_bytree=1.0
#   -> val RMSE: 0.7287
#
# Trying: max_depth=2, lr=0.01, n_estimators=800, subsample=1.0, colsample_bytree=0.8
#   -> val RMSE: 0.7322
#
# Trying: max_depth=2, lr=0.01, n_estimators=800, subsample=1.0, colsample_bytree=1.0
#   -> val RMSE: 0.7105
#
# Trying: max_depth=2, lr=0.05, n_estimators=500, subsample=0.8, colsample_bytree=0.8
#   -> val RMSE: 0.8578
#
# Trying: max_depth=2, lr=0.05, n_estimators=500, subsample=0.8, colsample_bytree=1.0
#   -> val RMSE: 0.9201
#
# Trying: max_depth=2, lr=0.05, n_estimators=500, subsample=1.0, colsample_bytree=0.8
#   -> val RMSE: 1.0382
#
# Trying: max_depth=2, lr=0.05, n_estimators=500, subsample=1.0, colsample_bytree=1.0
#   -> val RMSE: 0.9904
#
# Trying: max_depth=2, lr=0.05, n_estimators=600, subsample=0.8, colsample_bytree=0.8
#   -> val RMSE: 0.9044
#
# Trying: max_depth=2, lr=0.05, n_estimators=600, subsample=0.8, colsample_bytree=1.0
#   -> val RMSE: 0.9853
#
# Trying: max_depth=2, lr=0.05, n_estimators=600, subsample=1.0, colsample_bytree=0.8
#   -> val RMSE: 1.0724
#
# Trying: max_depth=2, lr=0.05, n_estimators=600, subsample=1.0, colsample_bytree=1.0
#   -> val RMSE: 1.0253
#
# Trying: max_depth=2, lr=0.05, n_estimators=800, subsample=0.8, colsample_bytree=0.8
#   -> val RMSE: 0.9440
#
# Trying: max_depth=2, lr=0.05, n_estimators=800, subsample=0.8, colsample_bytree=1.0
#   -> val RMSE: 1.0392
#
# Trying: max_depth=2, lr=0.05, n_estimators=800, subsample=1.0, colsample_bytree=0.8
#   -> val RMSE: 1.1320
#
# Trying: max_depth=2, lr=0.05, n_estimators=800, subsample=1.0, colsample_bytree=1.0
#   -> val RMSE: 1.0833
#
# Trying: max_depth=2, lr=0.07, n_estimators=500, subsample=0.8, colsample_bytree=0.8
#   -> val RMSE: 0.9970
#
# Trying: max_depth=2, lr=0.07, n_estimators=500, subsample=0.8, colsample_bytree=1.0
#   -> val RMSE: 1.0053
#
# Trying: max_depth=2, lr=0.07, n_estimators=500, subsample=1.0, colsample_bytree=0.8
#   -> val RMSE: 1.2340
#
# Trying: max_depth=2, lr=0.07, n_estimators=500, subsample=1.0, colsample_bytree=1.0
#   -> val RMSE: 1.1873
#
# Trying: max_depth=2, lr=0.07, n_estimators=600, subsample=0.8, colsample_bytree=0.8
#   -> val RMSE: 1.0159
#
# Trying: max_depth=2, lr=0.07, n_estimators=600, subsample=0.8, colsample_bytree=1.0
#   -> val RMSE: 1.0505
#
# Trying: max_depth=2, lr=0.07, n_estimators=600, subsample=1.0, colsample_bytree=0.8
#   -> val RMSE: 1.2920
#
# Trying: max_depth=2, lr=0.07, n_estimators=600, subsample=1.0, colsample_bytree=1.0
#   -> val RMSE: 1.2618
#
# Trying: max_depth=2, lr=0.07, n_estimators=800, subsample=0.8, colsample_bytree=0.8
#   -> val RMSE: 1.0522
#
# Trying: max_depth=2, lr=0.07, n_estimators=800, subsample=0.8, colsample_bytree=1.0
#   -> val RMSE: 1.0609
#
# Trying: max_depth=2, lr=0.07, n_estimators=800, subsample=1.0, colsample_bytree=0.8
#   -> val RMSE: 1.3374
#
# Trying: max_depth=2, lr=0.07, n_estimators=800, subsample=1.0, colsample_bytree=1.0
#   -> val RMSE: 1.3214
#
# Trying: max_depth=3, lr=0.01, n_estimators=500, subsample=0.8, colsample_bytree=0.8
#   -> val RMSE: 0.6292
#
# Trying: max_depth=3, lr=0.01, n_estimators=500, subsample=0.8, colsample_bytree=1.0
#   -> val RMSE: 0.5843
#
# Trying: max_depth=3, lr=0.01, n_estimators=500, subsample=1.0, colsample_bytree=0.8
#   -> val RMSE: 0.5542
#
# Trying: max_depth=3, lr=0.01, n_estimators=500, subsample=1.0, colsample_bytree=1.0
#   -> val RMSE: 0.5014
#
# Trying: max_depth=3, lr=0.01, n_estimators=600, subsample=0.8, colsample_bytree=0.8
#   -> val RMSE: 0.6470
#
# Trying: max_depth=3, lr=0.01, n_estimators=600, subsample=0.8, colsample_bytree=1.0
#   -> val RMSE: 0.6013
#
# Trying: max_depth=3, lr=0.01, n_estimators=600, subsample=1.0, colsample_bytree=0.8
#   -> val RMSE: 0.5840
#
# Trying: max_depth=3, lr=0.01, n_estimators=600, subsample=1.0, colsample_bytree=1.0
#   -> val RMSE: 0.5234
#
# Trying: max_depth=3, lr=0.01, n_estimators=800, subsample=0.8, colsample_bytree=0.8
#   -> val RMSE: 0.6914
#
# Trying: max_depth=3, lr=0.01, n_estimators=800, subsample=0.8, colsample_bytree=1.0
#   -> val RMSE: 0.6674
#
# Trying: max_depth=3, lr=0.01, n_estimators=800, subsample=1.0, colsample_bytree=0.8
#   -> val RMSE: 0.6506
#
# Trying: max_depth=3, lr=0.01, n_estimators=800, subsample=1.0, colsample_bytree=1.0
#   -> val RMSE: 0.5630
#
# Trying: max_depth=3, lr=0.05, n_estimators=500, subsample=0.8, colsample_bytree=0.8
#   -> val RMSE: 0.7913
#
# Trying: max_depth=3, lr=0.05, n_estimators=500, subsample=0.8, colsample_bytree=1.0
#   -> val RMSE: 0.7363
#
# Trying: max_depth=3, lr=0.05, n_estimators=500, subsample=1.0, colsample_bytree=0.8
#   -> val RMSE: 0.7571
#
# Trying: max_depth=3, lr=0.05, n_estimators=500, subsample=1.0, colsample_bytree=1.0
#   -> val RMSE: 0.7470
#
# Trying: max_depth=3, lr=0.05, n_estimators=600, subsample=0.8, colsample_bytree=0.8
#   -> val RMSE: 0.8028
#
# Trying: max_depth=3, lr=0.05, n_estimators=600, subsample=0.8, colsample_bytree=1.0
#   -> val RMSE: 0.7402
#
# Trying: max_depth=3, lr=0.05, n_estimators=600, subsample=1.0, colsample_bytree=0.8
#   -> val RMSE: 0.7702
#
# Trying: max_depth=3, lr=0.05, n_estimators=600, subsample=1.0, colsample_bytree=1.0
#   -> val RMSE: 0.7607
#
# Trying: max_depth=3, lr=0.05, n_estimators=800, subsample=0.8, colsample_bytree=0.8
#   -> val RMSE: 0.8138
#
# Trying: max_depth=3, lr=0.05, n_estimators=800, subsample=0.8, colsample_bytree=1.0
#   -> val RMSE: 0.7403
#
# Trying: max_depth=3, lr=0.05, n_estimators=800, subsample=1.0, colsample_bytree=0.8
#   -> val RMSE: 0.7843
#
# Trying: max_depth=3, lr=0.05, n_estimators=800, subsample=1.0, colsample_bytree=1.0
#   -> val RMSE: 0.7738
#
# Trying: max_depth=3, lr=0.07, n_estimators=500, subsample=0.8, colsample_bytree=0.8
#   -> val RMSE: 0.7907
#
# Trying: max_depth=3, lr=0.07, n_estimators=500, subsample=0.8, colsample_bytree=1.0
#   -> val RMSE: 0.8941
#
# Trying: max_depth=3, lr=0.07, n_estimators=500, subsample=1.0, colsample_bytree=0.8
#   -> val RMSE: 0.7957
#
# Trying: max_depth=3, lr=0.07, n_estimators=500, subsample=1.0, colsample_bytree=1.0
#   -> val RMSE: 0.9170
#
# Trying: max_depth=3, lr=0.07, n_estimators=600, subsample=0.8, colsample_bytree=0.8
#   -> val RMSE: 0.7904
#
# Trying: max_depth=3, lr=0.07, n_estimators=600, subsample=0.8, colsample_bytree=1.0
#   -> val RMSE: 0.8997
#
# Trying: max_depth=3, lr=0.07, n_estimators=600, subsample=1.0, colsample_bytree=0.8
#   -> val RMSE: 0.7971
#
# Trying: max_depth=3, lr=0.07, n_estimators=600, subsample=1.0, colsample_bytree=1.0
#   -> val RMSE: 0.9279
#
# Trying: max_depth=3, lr=0.07, n_estimators=800, subsample=0.8, colsample_bytree=0.8
#   -> val RMSE: 0.7922
#
# Trying: max_depth=3, lr=0.07, n_estimators=800, subsample=0.8, colsample_bytree=1.0
#   -> val RMSE: 0.9026
#
# Trying: max_depth=3, lr=0.07, n_estimators=800, subsample=1.0, colsample_bytree=0.8
#   -> val RMSE: 0.7946
#
# Trying: max_depth=3, lr=0.07, n_estimators=800, subsample=1.0, colsample_bytree=1.0
#   -> val RMSE: 0.9393
#
# Trying: max_depth=4, lr=0.01, n_estimators=500, subsample=0.8, colsample_bytree=0.8
#   -> val RMSE: 0.5495
#
# Trying: max_depth=4, lr=0.01, n_estimators=500, subsample=0.8, colsample_bytree=1.0
#   -> val RMSE: 0.5789
#
# Trying: max_depth=4, lr=0.01, n_estimators=500, subsample=1.0, colsample_bytree=0.8
#   -> val RMSE: 0.5491
#
# Trying: max_depth=4, lr=0.01, n_estimators=500, subsample=1.0, colsample_bytree=1.0
#   -> val RMSE: 0.5127
#
# Trying: max_depth=4, lr=0.01, n_estimators=600, subsample=0.8, colsample_bytree=0.8
#   -> val RMSE: 0.5692
#
# Trying: max_depth=4, lr=0.01, n_estimators=600, subsample=0.8, colsample_bytree=1.0
#   -> val RMSE: 0.6023
#
# Trying: max_depth=4, lr=0.01, n_estimators=600, subsample=1.0, colsample_bytree=0.8
#   -> val RMSE: 0.5969
#
# Trying: max_depth=4, lr=0.01, n_estimators=600, subsample=1.0, colsample_bytree=1.0
#   -> val RMSE: 0.5920
#
# Trying: max_depth=4, lr=0.01, n_estimators=800, subsample=0.8, colsample_bytree=0.8
#   -> val RMSE: 0.5975
#
# Trying: max_depth=4, lr=0.01, n_estimators=800, subsample=0.8, colsample_bytree=1.0
#   -> val RMSE: 0.6288
#
# Trying: max_depth=4, lr=0.01, n_estimators=800, subsample=1.0, colsample_bytree=0.8
#   -> val RMSE: 0.6759
#
# Trying: max_depth=4, lr=0.01, n_estimators=800, subsample=1.0, colsample_bytree=1.0
#   -> val RMSE: 0.6338
#
# Trying: max_depth=4, lr=0.05, n_estimators=500, subsample=0.8, colsample_bytree=0.8
#   -> val RMSE: 0.7083
#
# Trying: max_depth=4, lr=0.05, n_estimators=500, subsample=0.8, colsample_bytree=1.0
#   -> val RMSE: 0.7034
#
# Trying: max_depth=4, lr=0.05, n_estimators=500, subsample=1.0, colsample_bytree=0.8
#   -> val RMSE: 0.7874
#
# Trying: max_depth=4, lr=0.05, n_estimators=500, subsample=1.0, colsample_bytree=1.0
#   -> val RMSE: 0.8604
#
# Trying: max_depth=4, lr=0.05, n_estimators=600, subsample=0.8, colsample_bytree=0.8
#   -> val RMSE: 0.7102
#
# Trying: max_depth=4, lr=0.05, n_estimators=600, subsample=0.8, colsample_bytree=1.0
#   -> val RMSE: 0.7016
#
# Trying: max_depth=4, lr=0.05, n_estimators=600, subsample=1.0, colsample_bytree=0.8
#   -> val RMSE: 0.7902
#
# Trying: max_depth=4, lr=0.05, n_estimators=600, subsample=1.0, colsample_bytree=1.0
#   -> val RMSE: 0.8654
#
# Trying: max_depth=4, lr=0.05, n_estimators=800, subsample=0.8, colsample_bytree=0.8
#   -> val RMSE: 0.7109
#
# Trying: max_depth=4, lr=0.05, n_estimators=800, subsample=0.8, colsample_bytree=1.0
#   -> val RMSE: 0.7007
#
# Trying: max_depth=4, lr=0.05, n_estimators=800, subsample=1.0, colsample_bytree=0.8
#   -> val RMSE: 0.7942
#
# Trying: max_depth=4, lr=0.05, n_estimators=800, subsample=1.0, colsample_bytree=1.0
#   -> val RMSE: 0.8713
#
# Trying: max_depth=4, lr=0.07, n_estimators=500, subsample=0.8, colsample_bytree=0.8
#   -> val RMSE: 0.7383
#
# Trying: max_depth=4, lr=0.07, n_estimators=500, subsample=0.8, colsample_bytree=1.0
#   -> val RMSE: 0.7182
#
# Trying: max_depth=4, lr=0.07, n_estimators=500, subsample=1.0, colsample_bytree=0.8
#   -> val RMSE: 0.7847
#
# Trying: max_depth=4, lr=0.07, n_estimators=500, subsample=1.0, colsample_bytree=1.0
#   -> val RMSE: 0.7111
#
# Trying: max_depth=4, lr=0.07, n_estimators=600, subsample=0.8, colsample_bytree=0.8
#   -> val RMSE: 0.7382
#
# Trying: max_depth=4, lr=0.07, n_estimators=600, subsample=0.8, colsample_bytree=1.0
#   -> val RMSE: 0.7184
#
# Trying: max_depth=4, lr=0.07, n_estimators=600, subsample=1.0, colsample_bytree=0.8
#   -> val RMSE: 0.7868
#
# Trying: max_depth=4, lr=0.07, n_estimators=600, subsample=1.0, colsample_bytree=1.0
#   -> val RMSE: 0.7125
#
# Trying: max_depth=4, lr=0.07, n_estimators=800, subsample=0.8, colsample_bytree=0.8
#   -> val RMSE: 0.7385
#
# Trying: max_depth=4, lr=0.07, n_estimators=800, subsample=0.8, colsample_bytree=1.0
#   -> val RMSE: 0.7188
#
# Trying: max_depth=4, lr=0.07, n_estimators=800, subsample=1.0, colsample_bytree=0.8
#   -> val RMSE: 0.7875
#
# Trying: max_depth=4, lr=0.07, n_estimators=800, subsample=1.0, colsample_bytree=1.0
#   -> val RMSE: 0.7134
#
# Trying: max_depth=8, lr=0.01, n_estimators=500, subsample=0.8, colsample_bytree=0.8
#   -> val RMSE: 0.7387
#
# Trying: max_depth=8, lr=0.01, n_estimators=500, subsample=0.8, colsample_bytree=1.0
#   -> val RMSE: 0.7171
#
# Trying: max_depth=8, lr=0.01, n_estimators=500, subsample=1.0, colsample_bytree=0.8
#   -> val RMSE: 0.7090
#
# Trying: max_depth=8, lr=0.01, n_estimators=500, subsample=1.0, colsample_bytree=1.0
#   -> val RMSE: 0.6133
#
# Trying: max_depth=8, lr=0.01, n_estimators=600, subsample=0.8, colsample_bytree=0.8
#   -> val RMSE: 0.7393
#
# Trying: max_depth=8, lr=0.01, n_estimators=600, subsample=0.8, colsample_bytree=1.0
#   -> val RMSE: 0.7190
#
# Trying: max_depth=8, lr=0.01, n_estimators=600, subsample=1.0, colsample_bytree=0.8
#   -> val RMSE: 0.7016
#
# Trying: max_depth=8, lr=0.01, n_estimators=600, subsample=1.0, colsample_bytree=1.0
#   -> val RMSE: 0.6075
#
# Trying: max_depth=8, lr=0.01, n_estimators=800, subsample=0.8, colsample_bytree=0.8
#   -> val RMSE: 0.7466
#
# Trying: max_depth=8, lr=0.01, n_estimators=800, subsample=0.8, colsample_bytree=1.0
#   -> val RMSE: 0.7290
#
# Trying: max_depth=8, lr=0.01, n_estimators=800, subsample=1.0, colsample_bytree=0.8
#   -> val RMSE: 0.7012
#
# Trying: max_depth=8, lr=0.01, n_estimators=800, subsample=1.0, colsample_bytree=1.0
#   -> val RMSE: 0.6072
#
# Trying: max_depth=8, lr=0.05, n_estimators=500, subsample=0.8, colsample_bytree=0.8
#   -> val RMSE: 0.7307
#
# Trying: max_depth=8, lr=0.05, n_estimators=500, subsample=0.8, colsample_bytree=1.0
#   -> val RMSE: 0.7892
#
# Trying: max_depth=8, lr=0.05, n_estimators=500, subsample=1.0, colsample_bytree=0.8
#   -> val RMSE: 0.7056
#
# Trying: max_depth=8, lr=0.05, n_estimators=500, subsample=1.0, colsample_bytree=1.0
#   -> val RMSE: 0.6375
#
# Trying: max_depth=8, lr=0.05, n_estimators=600, subsample=0.8, colsample_bytree=0.8
#   -> val RMSE: 0.7308
#
# Trying: max_depth=8, lr=0.05, n_estimators=600, subsample=0.8, colsample_bytree=1.0
#   -> val RMSE: 0.7892
#
# Trying: max_depth=8, lr=0.05, n_estimators=600, subsample=1.0, colsample_bytree=0.8
#   -> val RMSE: 0.7056
#
# Trying: max_depth=8, lr=0.05, n_estimators=600, subsample=1.0, colsample_bytree=1.0
#   -> val RMSE: 0.6375
#
# Trying: max_depth=8, lr=0.05, n_estimators=800, subsample=0.8, colsample_bytree=0.8
#   -> val RMSE: 0.7308
#
# Trying: max_depth=8, lr=0.05, n_estimators=800, subsample=0.8, colsample_bytree=1.0
#   -> val RMSE: 0.7892
#
# Trying: max_depth=8, lr=0.05, n_estimators=800, subsample=1.0, colsample_bytree=0.8
#   -> val RMSE: 0.7056
#
# Trying: max_depth=8, lr=0.05, n_estimators=800, subsample=1.0, colsample_bytree=1.0
#   -> val RMSE: 0.6375
#
# Trying: max_depth=8, lr=0.07, n_estimators=500, subsample=0.8, colsample_bytree=0.8
#   -> val RMSE: 0.8238
#
# Trying: max_depth=8, lr=0.07, n_estimators=500, subsample=0.8, colsample_bytree=1.0
#   -> val RMSE: 0.8507
#
# Trying: max_depth=8, lr=0.07, n_estimators=500, subsample=1.0, colsample_bytree=0.8
#   -> val RMSE: 0.6686
#
# Trying: max_depth=8, lr=0.07, n_estimators=500, subsample=1.0, colsample_bytree=1.0
#   -> val RMSE: 0.6597
#
# Trying: max_depth=8, lr=0.07, n_estimators=600, subsample=0.8, colsample_bytree=0.8
#   -> val RMSE: 0.8238
#
# Trying: max_depth=8, lr=0.07, n_estimators=600, subsample=0.8, colsample_bytree=1.0
#   -> val RMSE: 0.8507
#
# Trying: max_depth=8, lr=0.07, n_estimators=600, subsample=1.0, colsample_bytree=0.8
#   -> val RMSE: 0.6686
#
# Trying: max_depth=8, lr=0.07, n_estimators=600, subsample=1.0, colsample_bytree=1.0
#   -> val RMSE: 0.6597
#
# Trying: max_depth=8, lr=0.07, n_estimators=800, subsample=0.8, colsample_bytree=0.8
#   -> val RMSE: 0.8238
#
# Trying: max_depth=8, lr=0.07, n_estimators=800, subsample=0.8, colsample_bytree=1.0
#   -> val RMSE: 0.8507
#
# Trying: max_depth=8, lr=0.07, n_estimators=800, subsample=1.0, colsample_bytree=0.8
#   -> val RMSE: 0.6686
#
# Trying: max_depth=8, lr=0.07, n_estimators=800, subsample=1.0, colsample_bytree=1.0
#   -> val RMSE: 0.6597
#     max_depth  learning_rate  n_estimators  subsample  colsample_bytree  \
# 39          3           0.01           500        1.0               1.0
# 75          4           0.01           500        1.0               1.0
# 43          3           0.01           600        1.0               1.0
# 74          4           0.01           500        1.0               0.8
# 72          4           0.01           500        0.8               0.8
#
#     val_rmse
# 39  0.501421
# 75  0.512740
# 43  0.523421
# 74  0.549104
# 72  0.549528

# %%
results_df = pd.DataFrame(results)
results_df = results_df.sort_values("val_rmse")
results_df.head()
# Out:
#     max_depth  learning_rate  n_estimators  subsample  colsample_bytree  \
# 39          3           0.01           500        1.0               1.0
# 75          4           0.01           500        1.0               1.0
# 43          3           0.01           600        1.0               1.0
# 74          4           0.01           500        1.0               0.8
# 72          4           0.01           500        0.8               0.8
#
#     val_rmse
# 39  0.501421
# 75  0.512740
# 43  0.523421
# 74  0.549104
# 72  0.549528

# %%
# Get the best row (lowest val_rmse)
best_params = results_df.iloc[0].to_dict()
print("Best params:", best_params)
# Out:
# Best params: {'max_depth': 3.0, 'learning_rate': 0.01, 'n_estimators': 500.0, 'subsample': 1.0, 'colsample_bytree': 1.0, 'val_rmse': 0.5014205131852878}

# %%
# Combine train_inner + val_df
full_train = pd.concat([train_inner, val_df]).sort_index()

X_full_train = full_train[feature_cols].values
y_full_train = full_train["Cases"].values

final_model = XGBRegressor(
    objective="reg:squarederror",
    max_depth=int(best_params["max_depth"]),
    learning_rate=float(best_params["learning_rate"]),
    n_estimators=int(best_params["n_estimators"]),
    subsample=float(best_params["subsample"]),
    colsample_bytree=float(best_params["colsample_bytree"]),
    random_state=42
)

final_model.fit(X_full_train, y_full_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=1.0, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.01, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=3,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=500,
#              n_jobs=None, num_parallel_tree=None, ...)

# %% [markdown]
# ## Evaluation Metrics

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

y_test_pred = final_model.predict(X_test)

mse  = mean_squared_error(y_test, y_test_pred)
rmse = np.sqrt(mse)
mae  = mean_absolute_error(y_test, y_test_pred)
r2   = r2_score(y_test, y_test_pred)

print("📊 Tuned XGBoost performance on TEST:")
print(f"MSE  : {mse:.4f}")
print(f"RMSE : {rmse:.4f}")
print(f"MAE  : {mae:.4f}")
print(f"R²   : {r2:.4f}")
# Out:
# 📊 Tuned XGBoost performance on TEST:
# MSE  : 8.9461
# RMSE : 2.9910
# MAE  : 1.2028
# R²   : 0.8514

# %% [markdown]
# ## Visualization

# %%
plt.figure(figsize=(12,6))
plt.plot(test.index, y_test,      label="Actual Cases",    color="black")
plt.plot(test.index, y_test_pred, label="Predicted Cases", color="red")
plt.title("Tuned XGBoost – Weekly Dengue Cases (Pingtung) – Test Set")
plt.xlabel("Date")
plt.ylabel("Weekly Cases")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8,10))
fi.head(20).plot(kind="barh", color="teal")
plt.gca().invert_yaxis()
plt.title("Top 20 Most Important Features – XGBoost")
plt.xlabel("Importance")
plt.ylabel("Feature")
plt.grid(True, axis="x", linestyle="--", alpha=0.5)
plt.show()

# %%
# %% [markdown]
# ## Save artifacts for Streamlit

import os, json

os.makedirs("../artifacts", exist_ok=True)

city_code = "pt"          # Pingtung
model_name = "xg"         # XGBoost

# 1) Save test predictions from the **tuned** model
pred_df = pd.DataFrame({
    "Date": test.index,        # weekly index
    "y_test": y_test,
    "y_pred": y_test_pred      # <--- tuned predictions
})
pred_path = f"../artifacts/{model_name}_{city_code}_predictions.csv"
pred_df.to_csv(pred_path, index=False)
print("Saved predictions to", pred_path)

# 2) Save feature importance (from tuned model)
fi_df = fi.to_frame(name="importance")   # fi already built from final_model
fi_path = f"../artifacts/{model_name}_{city_code}_feature_importance.csv"
fi_df.to_csv(fi_path)
print("Saved feature importance to", fi_path)

# 3) Save metrics (tuned)
metrics = {
    "MSE": float(mse),
    "RMSE": float(rmse),
    "MAE": float(mae),
    "R2": float(r2),
}
metrics_path = f"../artifacts/{model_name}_{city_code}_metrics.json"
with open(metrics_path, "w") as f:
    json.dump(metrics, f, indent=2)
print("Saved metrics to", metrics_path)

# 4) (Optional) save best hyperparameters
best_params_path = f"../artifacts/{model_name}_{city_code}_best_params.json"
with open(best_params_path, "w") as f:
    json.dump(best_params, f, indent=2)
print("Saved best params to", best_params_path)
# Out:
# Saved predictions to ../artifacts/xg_pt_predictions.csv
# Saved feature importance to ../artifacts/xg_pt_feature_importance.csv
# Saved metrics to ../artifacts/xg_pt_metrics.json
# Saved best params to ../artifacts/xg_pt_best_params.json
